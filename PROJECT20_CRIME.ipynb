# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv('crime.csv')

# %%
df=pd.DataFrame(ds)

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Area_Name                  1050 non-null   object
#  1   Year                       1050 non-null   int64
#  2   Subgroup                   1050 non-null   object
#  3   Rape_Cases_Reported        1050 non-null   int64
#  4   Victims_Above_50_Yrs       1050 non-null   int64
#  5   Victims_Between_10-14_Yrs  1050 non-null   int64
#  6   Victims_Between_14-18_Yrs  1050 non-null   int64
#  7   Victims_Between_18-30_Yrs  1050 non-null   int64
#  8   Victims_Between_30-50_Yrs  1050 non-null   int64
#  9   Victims_of_Rape_Total      1050 non-null   int64
#  10  Victims_Upto_10_Yrs        1050 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 90.4+ KB

# %%
df.shape
# Out:
# (1050, 11)

# %%
df['Area_Name'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
df['unreported_cases']=df['Victims_of_Rape_Total']-df['Rape_Cases_Reported']

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
u=df.groupby(['Area_Name']).sum()
u.drop('Year',axis=1,inplace=True)
u['unreported_cases'].max()
# Out:
# 118

# %%
u.sort_values(by='unreported_cases',ascending=False)
# Out:
#                            Rape_Cases_Reported  Victims_Above_50_Yrs  \
# Area_Name
# Maharashtra                              28892                   126
# Delhi                                    10292                    26
# Meghalaya                                 1452                     8
# Kerala                                   10592                   120
# Tamil Nadu                               11076                    24
# Punjab                                    8600                    26
# Rajasthan                                23898                   210
# Goa                                        532                    10
# Sikkim                                     290                     0
# Tripura                                   3248                     2
# Gujarat                                   6674                    16
# Manipur                                    542                     6
# ...

# %% [markdown]
# Highest unreported cases are found in Maharastra

# %%
u.sort_values(by='Victims_of_Rape_Total',ascending=False)
# Out:
#                            Rape_Cases_Reported  Victims_Above_50_Yrs  \
# Area_Name
# Madhya Pradesh                           58512                   362
# West Bengal                              32756                    20
# Uttar Pradesh                            30106                    24
# Maharashtra                              28892                   126
# Assam                                    25524                   190
# Rajasthan                                23898                   210
# Bihar                                    22526                    78
# Andhra Pradesh                           21392                   198
# Chhattisgarh                             19502                   226
# Odisha                                   17720                    60
# Jharkhand                                15126                    20
# Tamil Nadu                               11076                    24
# ...

# %% [markdown]
# we can see that highest rape case are found in MP and lowest rape case are found in Lakshadweep

# %%
u.sort_values(by='Victims_Above_50_Yrs',ascending=False)
# Out:
#                            Rape_Cases_Reported  Victims_Above_50_Yrs  \
# Area_Name
# Madhya Pradesh                           58512                   362
# Chhattisgarh                             19502                   226
# Rajasthan                                23898                   210
# Andhra Pradesh                           21392                   198
# Assam                                    25524                   190
# Maharashtra                              28892                   126
# Kerala                                   10592                   120
# Bihar                                    22526                    78
# Karnataka                                 7834                    68
# Haryana                                  10018                    62
# Odisha                                   17720                    60
# Himachal Pradesh                          2906                    36
# ...

# %% [markdown]
# victims of above 50 age are highest in MP and lowest in A&N

# %%
u.sort_values(by='Victims_Upto_10_Yrs',ascending=False)
# Out:
#                            Rape_Cases_Reported  Victims_Above_50_Yrs  \
# Area_Name
# Maharashtra                              28892                   126
# Madhya Pradesh                           58512                   362
# Delhi                                    10292                    26
# Andhra Pradesh                           21392                   198
# Uttar Pradesh                            30106                    24
# Chhattisgarh                             19502                   226
# Kerala                                   10592                   120
# Rajasthan                                23898                   210
# Tamil Nadu                               11076                    24
# Karnataka                                 7834                    68
# Gujarat                                   6674                    16
# Punjab                                    8600                    26
# ...

# %% [markdown]
# Highest child rape are found in Maharastra

# %% [markdown]
# # Dealing with Null Values

# %%
df.isnull().sum()
# Out:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# unreported_cases             0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# There is no null values in this dataset

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
df.Subgroup.unique()
# Out:
# array(['Total Rape Victims', 'Victims of Incest Rape',
#        'Victims of Other Rape'], dtype=object)

# %%
s=df.groupby('Subgroup').sum()
s.drop('Year',axis=1,inplace=True)

# %%
s
# Out:
#                         Rape_Cases_Reported  Victims_Above_50_Yrs  \
# Subgroup
# Total Rape Victims                   190008                   980
# Victims of Incest Rape                 4216                    26
# Victims of Other Rape                185792                   954
#
#                         Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# Subgroup
# Total Rape Victims                          12420                      27870
# Victims of Incest Rape                        513                       1042
# Victims of Other Rape                       11907                      26828
#
#                         Victims_Between_18-30_Yrs  Victims_Between_30-50_Yrs  \
# Subgroup
# Total Rape Victims                         111792                      31624
# Victims of Incest Rape                       1882                        517
# Victims of Other Rape                      109910                      31107
#
# ...

# %% [markdown]
# here we can see that there are total 190154 cases in which 4219 victims are victims of incest rape and 185935 victims are from other rapes

# %%
df.tail()
# Out:
#         Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 1045  West Bengal  2009  Victims of Incest Rape                    3
# 1046  West Bengal  2009   Victims of Other Rape                 2333
# 1047  West Bengal  2010      Total Rape Victims                 2311
# 1048  West Bengal  2010  Victims of Incest Rape                    4
# 1049  West Bengal  2010   Victims of Other Rape                 2307
#
#       Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 1045                     0                          0
# 1046                     0                         18
# 1047                     0                         22
# 1048                     0                          1
# 1049                     0                         21
#
#       Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 1045                          1                          1
# 1046                         84                       1834
# ...

# %%
df.shape
# Out:
# (1050, 12)

# %%
df.drop(df.loc[df['Subgroup']=='Total Rape Victims'].index,inplace=True)

# %%
df.shape
# Out:
# (700, 12)

# %%
df.tail()
# Out:
#         Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 1043  West Bengal  2008   Victims of Other Rape                 2254
# 1045  West Bengal  2009  Victims of Incest Rape                    3
# 1046  West Bengal  2009   Victims of Other Rape                 2333
# 1048  West Bengal  2010  Victims of Incest Rape                    4
# 1049  West Bengal  2010   Victims of Other Rape                 2307
#
#       Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 1043                     1                         51
# 1045                     0                          0
# 1046                     0                         18
# 1048                     0                          1
# 1049                     0                         21
#
#       Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 1043                         53                       1628
# 1045                          1                          1
# ...

# %% [markdown]
# # Rape in MP

# %%
mp=df[df['Area_Name']=='Madhya Pradesh']
mp
# Out:
#           Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 571  Madhya Pradesh  2001  Victims of Incest Rape                  301
# 572  Madhya Pradesh  2001   Victims of Other Rape                 2550
# 574  Madhya Pradesh  2002  Victims of Incest Rape                   72
# 575  Madhya Pradesh  2002   Victims of Other Rape                 2819
# 577  Madhya Pradesh  2003  Victims of Incest Rape                  123
# 578  Madhya Pradesh  2003   Victims of Other Rape                 2615
# 580  Madhya Pradesh  2004  Victims of Incest Rape                   63
# 581  Madhya Pradesh  2004   Victims of Other Rape                 2812
# 583  Madhya Pradesh  2005  Victims of Incest Rape                  141
# 584  Madhya Pradesh  2005   Victims of Other Rape                 2780
# 586  Madhya Pradesh  2006  Victims of Incest Rape                   29
# 587  Madhya Pradesh  2006   Victims of Other Rape                 2871
# ...

# %% [markdown]
# # EDA PROCESS

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=df['Subgroup'],y=df['Victims_of_Rape_Total'])
plt.tight_layout()

# %% [markdown]
# Here we can see that victims of other rape are higher than victims of incest rape

# %%
plt.figure(figsize=(16,10))
sns.barplot(x=df['Victims_of_Rape_Total'],y=df['Area_Name'],color='b')
plt.tight_layout()

# %% [markdown]
# Here we can see that the highest rape case are found in MP

# %%
plt.figure(figsize=(16,10))
sns.barplot(x=df['unreported_cases'],y=df['Area_Name'],color='b')
plt.tight_layout()

# %% [markdown]
# The highest unreported cases are found in Maharastra

# %%
plt.figure(figsize=(16,10))
sns.barplot(x=df['Victims_Upto_10_Yrs'],y=df['Area_Name'],color='b')
plt.tight_layout()

# %% [markdown]
# Highest child rape are found in maharastra

# %%
plt.figure(figsize=(16,10))
sns.barplot(x=df['Victims_Above_50_Yrs'],y=df['Area_Name'],color='g')
plt.tight_layout()

# %% [markdown]
# Highest old age rape are found in MP

# %%
plt.figure(figsize=(16,10))
sns.barplot(x=df['Rape_Cases_Reported'],y=df['Area_Name'],hue=df['Subgroup'])
plt.tight_layout()

# %% [markdown]
# Highest rape care are reported in MP
